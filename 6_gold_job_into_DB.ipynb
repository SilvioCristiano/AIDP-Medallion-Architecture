# %% [markdown]
# ## **Write the transformed and enhanced table to multiple databases for Anaytics or integration back to FDI** ##

# %%
silver_supplier_feedback_AI_join_csv = "silver_supplier_feedback_AI_Join_csv"

# %%
# Read managed silver tables
# Using spark.table
constructors_df = spark.table(f"silver_supplier.supplier_schema.silver_supplier_feedback_ai_join_csv")

# %%
# optionally change the table column names

constructors_final_df = constructors_df \
    .withColumnRenamed("supplier_name_silver", "supplier_name")\
    .withColumnRenamed("supplier_continent_silver", "continent")\
    .withColumnRenamed("supplier_country_silver", "country")\
    .withColumnRenamed("supplier_city_silver", "city")\
    .withColumnRenamed("summary_silver", "summary_review")\
    .withColumnRenamed("Rating", "rating")

# %%
# check the datafrome with new column names
try:
    constructors_final_df.show()

except ValueError as e:
    print("Invalid input:", e)
except ZeroDivisionError as e:
    print("Cannot divide by zero:", e)
except Exception as e: # Catch any other unexpected errors
    print("An unexpected error occurred:", e)
    print(type(e))
# Out:
# +--------------------+-------------+--------------------+-------------------+--------------------+------+
# |       supplier_name|    continent|             country|               city|      summary_review|rating|
# +--------------------+-------------+--------------------+-------------------+--------------------+------+
# |24/7 Community Ho...|North America|       United States|           Glendale|The reviewer prai...|     5|
# |     A1 Juice Supply|North America|       United States|             Aurora|This affordable, ...|     5|
# |            ABC Bank|North America|       United States|       Redwood City|The reviewer prai...|     5|
# |      ABC Consulting|      Oceania|           Australia|             Sydney|This product is h...|     4|
# |              Abbott|North America|       United States|        Lake Forest|The reviewer prai...|     5|
# |       Adams Leasing|North America|       United States|          Greenwood|Investing a littl...|     4|
# |       Advanced Corp|North America|       United States|          BALTIMORE|The reviewer prai...|     5|
# |        Aesculup Inc|North America|       United States|South San Francisco|This affordable c...|     3|
# |               Ajeer|         Asia|        Saudi Arabia|             Riyadh|The product gives...|     2|
# |Al Safa General C...|         Asia|United Arab Emirates|          Abu Dhabi|This all-tube amp...|     4|
# |          Al-Jeraisy|         Asia|        Saudi Arabia|             Riyadh|A guitar player p...|     5|
# |        Aljomaihauto|         Asia|        Saudi Arabia|             Riyadh|The MXL microphon...|     2|
# |Allied Manufacturing|North America|       United States|            DETROIT|This high-quality...|     5|
# |     Alps Consulting|       Europe|         Switzerland|              Vevey|The reviewer rate...|     3|
# |American Telephon...|North America|       United States|            ATLANTA|Recording vocals ...|     4|
# |     Antone Electric|North America|       United States|           Portland|The pop filter is...|     4|
# |   Anupam Contractor|         Asia|               India|              Delhi|The Wuhan 16" cra...|     4|
# |       Arec Computer|       Europe|               Italy|            Bologna|The reviewer purc...|     2|
# +--------------------+-------------+--------------------+-------------------+--------------------+------+

# %%
#  write the data frame into the database table
#  Using DataFrame overwrite
#  we could have used spark.sql,  sql, or data frame write or merge

try: 

   constructors_final_df.write.mode("overwrite").insertInto(f"supplier_external_26ai.admin.gold_supplier_feedback")
except ValueError as e:
    print("Invalid input:", e)
except ZeroDivisionError as e:
    print("Cannot divide by zero:", e)
except Exception as e: # Catch any other unexpected errors
    print("An unexpected error occurred:", e)
    print(type(e)) 
    
df = spark.read.table("supplier_external_26ai.admin.gold_supplier_feedback")
display (df)

# %%
# %sql
-- Can also query with SQL
select * from supplier_external_26ai.admin.gold_supplier_feedback
